# %% [markdown]
# <a href="https://colab.research.google.com/github/sagar-maheshwari01/python.assignment/blob/main/restfulAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RESTful API & Flask Assignment
#
# QUESTION-1. What is a RESTful API?
#
# ANSWER 1
#
# A RESTful API (Representational State Transfer API) is a web service that follows REST principles, allowing communication between clients and servers using HTTP methods like GET, POST, PUT, DELETE. It is stateless, scalable, and uses JSON or XML for data exchange.
#
# QUESTION 2. Explain the concept of API specification.
#
# ANSWER 2
#
# An API specification defines the rules, endpoints, request/response structures, authentication methods, and error handling for an API. Examples include OpenAPI (Swagger) and RAML.
#
# QUESTION 3. What is Flask, and why is it popular for building APIs?
#
# ANSWER 3
#
# Flask is a lightweight Python web framework used to build APIs. It is popular due to:
# 	•	Simplicity & flexibility
# 	•	Minimal boilerplate code
# 	•	Built-in development server
# 	•	Easy integration with databases and third-party libraries
#
# QUESTION 4. What is routing in Flask?
#
# ANSWER 4
#
# Routing in Flask maps URLs to functions, allowing users to define different endpoints.
#
# from flask import Flask
# app = Flask(__name__)
#
# @app.route('/')
# def home():
#     return "Hello, Flask!"

# %% [markdown]
#  How do you create a simple Flask application?
# 	1.	Install Flask: pip install flask
# 	2.	Create app.py:
#
#   from flask import Flask
# app = Flask(__name__)
#
# @app.route('/')
# def hello():
#     return "Welcome to Flask API!"
#
# if __name__ == '__main__':
#     app.run(debug=True)
#
#   3.	Run: python app.py

# %% [markdown]
# Q-6. What are HTTP methods used in RESTful APIs?
#
# ANS -6
#
# 	•	GET – Retrieve data
# 	•	POST – Create new resource
# 	•	PUT – Update existing resource
# 	•	DELETE – Remove resource
# 	•	PATCH – Partially update resource
#
# QUESTION 7. What is the purpose of the @app.route() decorator in Flask?
#
# ANSWER 7
#
# It defines URL routes and links them to Python functions.
#
# question 9. How do you handle errors in Flask APIs?
#
# ANSWER
#
# Using Flask’s errorhandler:
# @app.errorhandler(404)
# def not_found(error):
#     return {"error": "Not found"}, 404
#
#
# question 10. How do you connect Flask to a SQL database?
#
# ANSWER
#
# Using Flask-SQLAlchemy:
# from flask_sqlalchemy import SQLAlchemy
# app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///database.db'
# db = SQLAlchemy(app)
#
# QUESTION 11. What is the role of Flask-SQLAlchemy?
#
# ANSWER
#
# It simplifies database interactions using an ORM (Object-Relational Mapper).
#
# Question 12. What are Flask blueprints, and how are they useful?
#
#  ANSWER
#
# Blueprints allow modular structuring of Flask apps by defining multiple route groups.
#
# Question 13. What is the purpose of Flask’s request object?
#
# ANSWER
#
#
# The request object provides access to HTTP request data (headers, parameters, JSON body).
# from flask import request
# @app.route('/data', methods=['POST'])
# def get_data():
#     return request.json
#
# Question 14. How do you create a RESTful API endpoint using Flask?
#
# ANSWER
#
# @app.route('/users/<int:id>', methods=['GET'])
# def get_user(id):
#     return {"id": id, "name": "John Doe"}
#
#     Question 15. What is the purpose of Flask’s jsonify() function?
#
# It converts Python dictionaries to JSON format.
#
# from flask import jsonify
# jsonify({"message": "Success"})
#
# Question 16. Explain Flask’s url_for() function.
#
# ANSWER
#
# Generates URLs dynamically:
#
# url_for('home')  # Generates '/'
#
# Question 17. How does Flask handle static files (CSS, JavaScript, etc.)?
#
#
#  ANSWER
#
#
# Stores them in a “static” folder and accesses via url_for('static', filename='style.css').
#
# QUESTION 18. What are HTTP status codes, and why are they important in a Flask API?
#
#
# ANSWER
#
# They indicate the result of an HTTP request, e.g.,
# 	•	200 OK – Success
# 	•	404 Not Found – Resource missing
# 	•	500 Internal Server Error – Server issue
#
# QUESTION 19. How do you handle POST requests in Flask?
#
# ANSWER
#
# Using request.form or request.json:
# @app.route('/submit', methods=['POST'])
# def submit():
#     data = request.json
#     return {"received": data}
#
# question 20. How would you secure a Flask API?
#
# ANSWER
#
# 	•	Use JWT authentication
# 	•	Implement rate limiting
# 	•	Enable HTTPS
# 	•	Validate & sanitize input data
#
# QUESTION 21. What is the significance of the Flask-RESTful extension?
#
# ANSWER
#
# It simplifies building REST APIs with class-based views.
#
# QUESTION 22. What is the role of Flask’s session object?
#
# ANSWER
#
# Used to store user-specific data across requests.
